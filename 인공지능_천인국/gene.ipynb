# %%
import random

POPULATION_SIZE = 4
MUTATION_RATE = 0.1
SIZE = 5

# 염색체를 클래스로 정의한다. 
class Chromosome:
    def __init__(self, g=[]):
        self.genes = g.copy()		# 유전자는 리스트로 구현된다. 
        self.fitness = 0		# 적합도
        if self.genes.__len__()==0:	# 염색체가 초기 상태이면 초기화한다. 
            i = 0
            while i<SIZE:
                if random.random() >= 0.5: self.genes.append(1)
                else: self.genes.append(0)
                i += 1
    
    def cal_fitness(self):		# 적합도를 계산한다. 
        self.fitness = 0;
        value = 0
        for i in range(SIZE):
            value += self.genes[i]*pow(2,SIZE-1-i)
        self.fitness = value
        return self.fitness

    def __str__(self):
        return self.genes.__str__()
# 염색체와 적합도를 출력한다. 
def print_p(pop):
    i = 0
    for x in pop:
        print("염색체 #", i, "=", x, "적합도=", x.cal_fitness())
        i += 1
    print("")

# 선택 연산
def select(pop):
    max_value  = sum([c.cal_fitness() for c in population])
    pick    = random.uniform(0, max_value)
    current = 0
    
    # 룰렛휠에서 어떤 조각에 속하는지를 알아내는 루프
    for c in pop:
        current += c.cal_fitness()
        if current > pick:
            return c
# 교차 연산
def crossover(pop):
    father = select(pop)
    mother = select(pop)
    index = random.randint(1, SIZE - 2)
    child1 = father.genes[:index] + mother.genes[index:] 
    child2 = mother.genes[:index] + father.genes[index:] 
    return (child1, child2)
    
# 돌연변이 연산
def mutate(c):
    for i in range(SIZE):
        if random.random() < MUTATION_RATE:
            if random.random() < 0.5:
                c.genes[i] = 1
            else:
                c.genes[i] = 0

# 메인 프로그램
population = []
i=0

# 초기 염색체를 생성하여 객체 집단에 추가한다. 
while i<POPULATION_SIZE:
    population.append(Chromosome())
    i += 1

count=0
population.sort(key=lambda x: x.cal_fitness(), reverse=True)
print("세대 번호=", count)
print_p(population)
count=1
while population[0].cal_fitness() < 31:
    new_pop = []

    # 선택과 교차 연산
    for _ in range(POPULATION_SIZE//2):
        c1, c2 = crossover(population);
        new_pop.append(Chromosome(c1));
        new_pop.append(Chromosome(c2));

    # 자식 세대가 부모 세대를 대체한다. 
    # 깊은 복사를 수행한다. 
    population = new_pop.copy();    
    
    # 돌연변이 연산
    for c in population: mutate(c)

    # 출력을 위한 정렬
    population.sort(key=lambda x: x.cal_fitness(), reverse=True)
    print("세대 번호=", count)
    print_p(population)
    count += 1
    if count > 100 : break;
# Out:
# 세대 번호= 0
# 염색체 # 0 = [1, 0, 0, 0, 0] 적합도= 16
# 염색체 # 1 = [0, 1, 1, 0, 0] 적합도= 12
# 염색체 # 2 = [0, 1, 0, 1, 1] 적합도= 11
# 염색체 # 3 = [0, 1, 0, 0, 0] 적합도= 8
#
# 세대 번호= 1
# 염색체 # 0 = [1, 1, 0, 0, 0] 적합도= 24
# 염색체 # 1 = [0, 1, 0, 1, 1] 적합도= 11
# 염색체 # 2 = [0, 1, 0, 0, 0] 적합도= 8
# 염색체 # 3 = [0, 0, 0, 0, 0] 적합도= 0
#
# 세대 번호= 2
# 염색체 # 0 = [1, 1, 0, 1, 0] 적합도= 26
# 염색체 # 1 = [1, 1, 0, 0, 0] 적합도= 24
# 염색체 # 2 = [1, 0, 0, 0, 0] 적합도= 16
# 염색체 # 3 = [0, 1, 0, 0, 0] 적합도= 8
#
# 세대 번호= 3
# 염색체 # 0 = [1, 1, 1, 0, 0] 적합도= 28
# 염색체 # 1 = [1, 1, 0, 1, 0] 적합도= 26
# 염색체 # 2 = [1, 1, 0, 0, 0] 적합도= 24
# 염색체 # 3 = [0, 1, 0, 1, 0] 적합도= 10
#
# 세대 번호= 4
# 염색체 # 0 = [1, 1, 1, 0, 0] 적합도= 28
# 염색체 # 1 = [1, 1, 0, 1, 0] 적합도= 26
# 염색체 # 2 = [1, 1, 0, 0, 0] 적합도= 24
# 염색체 # 3 = [0, 1, 0, 1, 0] 적합도= 10
#
# 세대 번호= 5
# 염색체 # 0 = [1, 1, 1, 1, 0] 적합도= 30
# 염색체 # 1 = [1, 1, 1, 0, 0] 적합도= 28
# 염색체 # 2 = [1, 1, 0, 0, 0] 적합도= 24
# 염색체 # 3 = [0, 1, 0, 0, 0] 적합도= 8
#
# 세대 번호= 6
# 염색체 # 0 = [1, 1, 0, 0, 0] 적합도= 24
# 염색체 # 1 = [1, 1, 0, 0, 0] 적합도= 24
# 염색체 # 2 = [0, 1, 0, 0, 0] 적합도= 8
# 염색체 # 3 = [0, 1, 0, 0, 0] 적합도= 8
#
# 세대 번호= 7
# 염색체 # 0 = [1, 1, 0, 0, 0] 적합도= 24
# 염색체 # 1 = [1, 0, 0, 0, 0] 적합도= 16
# 염색체 # 2 = [0, 1, 0, 0, 0] 적합도= 8
# 염색체 # 3 = [0, 1, 0, 0, 0] 적합도= 8
#
# 세대 번호= 8
# 염색체 # 0 = [1, 1, 0, 0, 0] 적합도= 24
# 염색체 # 1 = [1, 0, 0, 0, 1] 적합도= 17
# 염색체 # 2 = [1, 0, 0, 0, 0] 적합도= 16
# 염색체 # 3 = [0, 0, 0, 0, 0] 적합도= 0
#
# 세대 번호= 9
# 염색체 # 0 = [1, 1, 0, 0, 1] 적합도= 25
# 염색체 # 1 = [1, 0, 1, 0, 0] 적합도= 20
# 염색체 # 2 = [1, 0, 0, 0, 1] 적합도= 17
# 염색체 # 3 = [1, 0, 0, 0, 0] 적합도= 16
#
# 세대 번호= 10
# 염색체 # 0 = [1, 1, 0, 1, 1] 적합도= 27
# 염색체 # 1 = [1, 0, 1, 0, 0] 적합도= 20
# 염색체 # 2 = [1, 0, 0, 1, 0] 적합도= 18
# 염색체 # 3 = [1, 0, 0, 0, 1] 적합도= 17
#
# 세대 번호= 11
# 염색체 # 0 = [1, 1, 1, 0, 0] 적합도= 28
# 염색체 # 1 = [1, 0, 1, 0, 0] 적합도= 20
# 염색체 # 2 = [1, 0, 0, 1, 0] 적합도= 18
# 염색체 # 3 = [0, 0, 1, 0, 0] 적합도= 4
#
# 세대 번호= 12
# 염색체 # 0 = [1, 1, 1, 0, 0] 적합도= 28
# 염색체 # 1 = [1, 1, 0, 0, 0] 적합도= 24
# 염색체 # 2 = [0, 0, 1, 0, 0] 적합도= 4
# 염색체 # 3 = [0, 0, 1, 0, 0] 적합도= 4
#
# 세대 번호= 13
# 염색체 # 0 = [1, 1, 1, 0, 0] 적합도= 28
# 염색체 # 1 = [1, 1, 1, 0, 0] 적합도= 28
# 염색체 # 2 = [1, 1, 0, 0, 0] 적합도= 24
# 염색체 # 3 = [0, 1, 0, 0, 0] 적합도= 8
#
# 세대 번호= 14
# 염색체 # 0 = [1, 1, 1, 0, 0] 적합도= 28
# 염색체 # 1 = [1, 1, 1, 0, 0] 적합도= 28
# 염색체 # 2 = [1, 1, 0, 0, 0] 적합도= 24
# 염색체 # 3 = [1, 0, 0, 0, 0] 적합도= 16
#
# 세대 번호= 15
# 염색체 # 0 = [1, 1, 1, 0, 1] 적합도= 29
# 염색체 # 1 = [1, 1, 1, 0, 0] 적합도= 28
# 염색체 # 2 = [1, 1, 0, 0, 0] 적합도= 24
# 염색체 # 3 = [1, 0, 0, 0, 0] 적합도= 16
#
# 세대 번호= 16
# 염색체 # 0 = [1, 1, 1, 0, 1] 적합도= 29
# 염색체 # 1 = [1, 1, 1, 0, 0] 적합도= 28
# 염색체 # 2 = [1, 1, 1, 0, 0] 적합도= 28
# 염색체 # 3 = [1, 0, 0, 0, 0] 적합도= 16
#
# 세대 번호= 17
# 염색체 # 0 = [1, 1, 1, 0, 1] 적합도= 29
# 염색체 # 1 = [1, 1, 1, 0, 0] 적합도= 28
# 염색체 # 2 = [1, 1, 1, 0, 0] 적합도= 28
# 염색체 # 3 = [1, 1, 1, 0, 0] 적합도= 28
#
# 세대 번호= 18
# 염색체 # 0 = [1, 1, 1, 0, 1] 적합도= 29
# 염색체 # 1 = [1, 1, 1, 0, 1] 적합도= 29
# 염색체 # 2 = [1, 1, 1, 0, 0] 적합도= 28
# 염색체 # 3 = [1, 1, 1, 0, 0] 적합도= 28
#
# 세대 번호= 19
# 염색체 # 0 = [1, 1, 1, 1, 0] 적합도= 30
# 염색체 # 1 = [1, 1, 1, 0, 1] 적합도= 29
# 염색체 # 2 = [1, 1, 1, 0, 1] 적합도= 29
# 염색체 # 3 = [1, 1, 1, 0, 0] 적합도= 28
#
# 세대 번호= 20
# 염색체 # 0 = [1, 1, 1, 1, 0] 적합도= 30
# 염색체 # 1 = [1, 1, 1, 0, 1] 적합도= 29
# 염색체 # 2 = [1, 1, 0, 0, 1] 적합도= 25
# 염색체 # 3 = [0, 1, 1, 0, 0] 적합도= 12
#
# 세대 번호= 21
# 염색체 # 0 = [1, 1, 1, 1, 0] 적합도= 30
# 염색체 # 1 = [1, 1, 1, 0, 1] 적합도= 29
# 염색체 # 2 = [1, 1, 0, 0, 1] 적합도= 25
# 염색체 # 3 = [1, 1, 0, 0, 1] 적합도= 25
#
# 세대 번호= 22
# 염색체 # 0 = [1, 1, 1, 1, 0] 적합도= 30
# 염색체 # 1 = [1, 1, 1, 1, 0] 적합도= 30
# 염색체 # 2 = [1, 1, 0, 0, 1] 적합도= 25
# 염색체 # 3 = [1, 0, 1, 1, 0] 적합도= 22
#
# 세대 번호= 23
# 염색체 # 0 = [1, 1, 1, 1, 0] 적합도= 30
# 염색체 # 1 = [1, 1, 1, 1, 0] 적합도= 30
# 염색체 # 2 = [1, 1, 1, 0, 0] 적합도= 28
# 염색체 # 3 = [1, 1, 0, 0, 1] 적합도= 25
#
# 세대 번호= 24
# 염색체 # 0 = [1, 1, 1, 1, 0] 적합도= 30
# 염색체 # 1 = [1, 1, 1, 1, 0] 적합도= 30
# 염색체 # 2 = [1, 1, 1, 1, 0] 적합도= 30
# 염색체 # 3 = [0, 1, 0, 0, 1] 적합도= 9
#
# 세대 번호= 25
# 염색체 # 0 = [1, 1, 1, 1, 0] 적합도= 30
# 염색체 # 1 = [1, 1, 1, 1, 0] 적합도= 30
# 염색체 # 2 = [1, 1, 1, 1, 0] 적합도= 30
# 염색체 # 3 = [1, 0, 0, 1, 0] 적합도= 18
#
# 세대 번호= 26
# 염색체 # 0 = [1, 1, 1, 1, 0] 적합도= 30
# 염색체 # 1 = [1, 1, 1, 1, 0] 적합도= 30
# 염색체 # 2 = [1, 1, 1, 1, 0] 적합도= 30
# 염색체 # 3 = [1, 0, 0, 1, 0] 적합도= 18
#
# 세대 번호= 27
# 염색체 # 0 = [1, 1, 1, 1, 0] 적합도= 30
# 염색체 # 1 = [1, 1, 1, 1, 0] 적합도= 30
# 염색체 # 2 = [1, 1, 1, 1, 0] 적합도= 30
# 염색체 # 3 = [1, 1, 0, 1, 0] 적합도= 26
#
# 세대 번호= 28
# 염색체 # 0 = [1, 1, 1, 1, 0] 적합도= 30
# 염색체 # 1 = [1, 1, 1, 1, 0] 적합도= 30
# 염색체 # 2 = [1, 1, 0, 1, 0] 적합도= 26
# 염색체 # 3 = [1, 0, 1, 1, 0] 적합도= 22
#
# 세대 번호= 29
# 염색체 # 0 = [1, 1, 1, 1, 0] 적합도= 30
# 염색체 # 1 = [1, 1, 1, 1, 0] 적합도= 30
# 염색체 # 2 = [1, 1, 0, 1, 0] 적합도= 26
# 염색체 # 3 = [1, 0, 0, 1, 0] 적합도= 18
#
# 세대 번호= 30
# 염색체 # 0 = [1, 1, 1, 1, 0] 적합도= 30
# 염색체 # 1 = [1, 1, 1, 1, 0] 적합도= 30
# 염색체 # 2 = [1, 0, 1, 1, 0] 적합도= 22
# 염색체 # 3 = [1, 0, 0, 1, 0] 적합도= 18
#
# 세대 번호= 31
# 염색체 # 0 = [1, 1, 1, 1, 0] 적합도= 30
# 염색체 # 1 = [1, 1, 1, 1, 0] 적합도= 30
# 염색체 # 2 = [1, 0, 1, 0, 1] 적합도= 21
# 염색체 # 3 = [1, 0, 1, 0, 0] 적합도= 20
#
# 세대 번호= 32
# 염색체 # 0 = [1, 1, 1, 1, 0] 적합도= 30
# 염색체 # 1 = [1, 1, 1, 0, 1] 적합도= 29
# 염색체 # 2 = [1, 0, 1, 1, 0] 적합도= 22
# 염색체 # 3 = [0, 0, 1, 0, 1] 적합도= 5
#
# 세대 번호= 33
# 염색체 # 0 = [1, 0, 1, 1, 0] 적합도= 22
# 염색체 # 1 = [1, 0, 1, 1, 0] 적합도= 22
# 염색체 # 2 = [1, 0, 1, 0, 1] 적합도= 21
# 염색체 # 3 = [0, 1, 1, 1, 0] 적합도= 14
#
# 세대 번호= 34
# 염색체 # 0 = [1, 0, 1, 0, 1] 적합도= 21
# 염색체 # 1 = [0, 1, 1, 1, 0] 적합도= 14
# 염색체 # 2 = [0, 0, 1, 1, 0] 적합도= 6
# 염색체 # 3 = [0, 0, 1, 1, 0] 적합도= 6
#
# 세대 번호= 35
# 염색체 # 0 = [1, 0, 1, 1, 1] 적합도= 23
# 염색체 # 1 = [1, 0, 1, 1, 0] 적합도= 22
# 염색체 # 2 = [1, 0, 1, 0, 1] 적합도= 21
# 염색체 # 3 = [0, 1, 1, 0, 1] 적합도= 13
#
# 세대 번호= 36
# 염색체 # 0 = [1, 0, 1, 1, 1] 적합도= 23
# 염색체 # 1 = [1, 0, 1, 1, 0] 적합도= 22
# 염색체 # 2 = [1, 0, 1, 0, 1] 적합도= 21
# 염색체 # 3 = [0, 0, 1, 0, 1] 적합도= 5
#
# 세대 번호= 37
# 염색체 # 0 = [1, 1, 1, 1, 0] 적합도= 30
# 염색체 # 1 = [1, 0, 1, 1, 1] 적합도= 23
# 염색체 # 2 = [1, 0, 1, 0, 1] 적합도= 21
# 염색체 # 3 = [1, 0, 1, 0, 1] 적합도= 21
#
# 세대 번호= 38
# 염색체 # 0 = [1, 1, 1, 1, 0] 적합도= 30
# 염색체 # 1 = [1, 1, 1, 0, 0] 적합도= 28
# 염색체 # 2 = [1, 0, 1, 1, 0] 적합도= 22
# 염색체 # 3 = [1, 0, 1, 0, 1] 적합도= 21
#
# 세대 번호= 39
# 염색체 # 0 = [1, 1, 1, 1, 0] 적합도= 30
# 염색체 # 1 = [1, 1, 1, 1, 0] 적합도= 30
# 염색체 # 2 = [1, 1, 1, 0, 0] 적합도= 28
# 염색체 # 3 = [1, 0, 1, 0, 0] 적합도= 20
#
# 세대 번호= 40
# 염색체 # 0 = [1, 1, 1, 0, 0] 적합도= 28
# 염색체 # 1 = [1, 1, 1, 0, 0] 적합도= 28
# 염색체 # 2 = [1, 0, 1, 1, 0] 적합도= 22
# 염색체 # 3 = [0, 1, 1, 1, 0] 적합도= 14
#
# 세대 번호= 41
# 염색체 # 0 = [1, 1, 1, 1, 0] 적합도= 30
# 염색체 # 1 = [1, 1, 1, 1, 0] 적합도= 30
# 염색체 # 2 = [0, 1, 1, 0, 0] 적합도= 12
# 염색체 # 3 = [0, 0, 1, 1, 0] 적합도= 6
#
# 세대 번호= 42
# 염색체 # 0 = [1, 1, 1, 1, 0] 적합도= 30
# 염색체 # 1 = [0, 1, 1, 1, 0] 적합도= 14
# 염색체 # 2 = [0, 1, 1, 0, 0] 적합도= 12
# 염색체 # 3 = [0, 0, 1, 1, 0] 적합도= 6
#
# 세대 번호= 43
# 염색체 # 0 = [1, 1, 1, 1, 1] 적합도= 31
# 염색체 # 1 = [1, 1, 1, 1, 0] 적합도= 30
# 염색체 # 2 = [1, 1, 1, 1, 0] 적합도= 30
# 염색체 # 3 = [0, 1, 1, 1, 0] 적합도= 14
