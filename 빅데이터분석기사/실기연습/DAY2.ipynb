# %% [markdown]
# boston data세트의 TAX 칼럼이 TAX 칼럼의 중위값보다 큰 데이터를 대상으로, CHAS 칼럼과 RAD칼럼 순으로 그룹을 지은 후 각 그룹의 데이터 개수를 구하시오. 단 각 칼럼별 데이터 개수는 COUNT라는 칼럼으로 출력합니다.

# %%
import pandas as pd
data = pd.read_csv("https://raw.githubusercontent.com/7ieon/bigData/main/boston.csv")
data
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573    NaN  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# 2       17.8  392.83   4.03  34.7
# 3       18.7  394.63   2.94  33.4
# 4       18.7  396.90   5.33  36.2
# ..       ...     ...    ...   ...
# 501     21.0  391.99   9.67  22.4
# 502     21.0  396.90   9.08  20.6
# 503     21.0  396.90   5.64  23.9
# 504     21.0  393.45   6.48  22.0
# 505     21.0  396.90   7.88  11.9
#
# [506 rows x 14 columns]

# %%
tax_median = data['TAX'].median()
print(tax_median)
# Out:
# 330.0

# %%
print(data['TAX']>tax_median)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 501    False
# 502    False
# 503    False
# 504    False
# 505    False
# Name: TAX, Length: 506, dtype: bool

# %%
print(data[data['TAX']>tax_median])
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 54   0.01360  75.0   4.00     0  0.410  5.888  47.6  7.3197    3  469
# 65   0.03584  80.0   3.37     0  0.398  6.290  17.8  6.6115    4  337
# 66   0.04379  80.0   3.37     0  0.398  5.787  31.1  6.6115    4  337
# 67   0.05789  12.5   6.07     0  0.409  5.878  21.4  6.4980    4  345
# 68   0.13554  12.5   6.07     0  0.409  5.594  36.8  6.4980    4  345
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 496  0.28960   0.0   9.69     0  0.585  5.390  72.9  2.7986    6  391
# 497  0.26838   0.0   9.69     0  0.585    NaN  70.6  2.8927    6  391
# 498  0.23912   0.0   9.69     0  0.585  6.019  65.3  2.4091    6  391
# 499  0.17783   0.0   9.69     0  0.585  5.569  73.5  2.3999    6  391
# 500  0.22438   0.0   9.69     0  0.585  6.027  79.7  2.4982    6  391
#
#      PTRATIO       B  LSTAT  MEDV
# 54      21.1  396.90  14.80  18.9
# 65      16.1  396.90   4.67  23.5
# 66      16.1  396.90  10.24  19.4
# 67      18.9  396.21   8.10  22.0
# 68      18.9  396.90  13.09  17.4
# ..       ...     ...    ...   ...
# 496     19.2  396.90  21.14  19.7
# 497     19.2  396.90  14.10  18.3
# 498     19.2  396.90  12.92  21.2
# 499     19.2  395.77  15.10  17.5
# 500     19.2  396.90  14.33  16.8
#
# [250 rows x 14 columns]

# %%
data[data['TAX']>tax_median]
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 54   0.01360  75.0   4.00     0  0.410  5.888  47.6  7.3197    3  469
# 65   0.03584  80.0   3.37     0  0.398  6.290  17.8  6.6115    4  337
# 66   0.04379  80.0   3.37     0  0.398  5.787  31.1  6.6115    4  337
# 67   0.05789  12.5   6.07     0  0.409  5.878  21.4  6.4980    4  345
# 68   0.13554  12.5   6.07     0  0.409  5.594  36.8  6.4980    4  345
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 496  0.28960   0.0   9.69     0  0.585  5.390  72.9  2.7986    6  391
# 497  0.26838   0.0   9.69     0  0.585    NaN  70.6  2.8927    6  391
# 498  0.23912   0.0   9.69     0  0.585  6.019  65.3  2.4091    6  391
# 499  0.17783   0.0   9.69     0  0.585  5.569  73.5  2.3999    6  391
# 500  0.22438   0.0   9.69     0  0.585  6.027  79.7  2.4982    6  391
#
#      PTRATIO       B  LSTAT  MEDV
# 54      21.1  396.90  14.80  18.9
# 65      16.1  396.90   4.67  23.5
# 66      16.1  396.90  10.24  19.4
# 67      18.9  396.21   8.10  22.0
# 68      18.9  396.90  13.09  17.4
# ..       ...     ...    ...   ...
# 496     19.2  396.90  21.14  19.7
# 497     19.2  396.90  14.10  18.3
# 498     19.2  396.90  12.92  21.2
# 499     19.2  395.77  15.10  17.5
# 500     19.2  396.90  14.33  16.8
#
# [250 rows x 14 columns]

# %%
print(data[data['TAX']>tax_median][['CHAS','RAD']])
# Out:
#      CHAS  RAD
# 54      0    3
# 65      0    4
# 66      0    4
# 67      0    4
# 68      0    4
# ..    ...  ...
# 496     0    6
# 497     0    6
# 498     0    6
# 499     0    6
# 500     0    6
#
# [250 rows x 2 columns]

# %%
data_new=data[data['TAX']>tax_median][['CHAS','RAD']]
data_new
# Out:
#      CHAS  RAD
# 54      0    3
# 65      0    4
# 66      0    4
# 67      0    4
# 68      0    4
# ..    ...  ...
# 496     0    6
# 497     0    6
# 498     0    6
# 499     0    6
# 500     0    6
#
# [250 rows x 2 columns]

# %%
print(data_new['CHAS'].unique())
print(data_new['RAD'].unique())
# Out:
# [0 1]
# [ 3  4  5  6  2  1 24]

# %%
data_new2 = data_new.groupby(['CHAS','RAD'])['RAD'].count()
print(data_new2)
# Out:
# CHAS  RAD
# 0     1        3
#       2        2
#       3        5
#       4       33
#       5       51
#       6       17
#       24     124
# 1     5        7
#       24       8
# Name: RAD, dtype: int64

# %%
data_new3=pd.DataFrame(data_new2)
data_new3.columns=['COUNT']
data_new3
# Out:
#           COUNT
# CHAS RAD
# 0    1        3
#      2        2
#      3        5
#      4       33
#      5       51
#      6       17
#      24     124
# 1    5        7
#      24       8

# %%
# data_new3=pd.DataFrame(data_new2)
data_new2.columns=['CHAS','RAD','COUNT']

# %%
data_new2
# Out:
# CHAS  RAD
# 0     1        3
#       2        2
#       3        5
#       4       33
#       5       51
#       6       17
#       24     124
# 1     5        7
#       24       8
# Name: RAD, dtype: int64

# %%
data_new4=data_new.groupby(['CHAS','RAD'])['RAD'].count()
print(data_new4)
# Out:
# CHAS  RAD
# 0     1        3
#       2        2
#       3        5
#       4       33
#       5       51
#       6       17
#       24     124
# 1     5        7
#       24       8
# Name: RAD, dtype: int64

# %% [markdown]
# Boston 데이터 세트의 TAX칼럼을 오름차순으로 정렬한 결과와 내림차순으로 정렬한 결과를 각각 구한다. 그리고 각 순번에 맞는 오름차순 값과 내림차순 값의 차이를 구하여 분산 값을 출력하시오.

# %%
data_asc = data['TAX'].copy()
data_desc = data['TAX'].copy()
data_asc.sort_values(ascending=True,inplace=True)
data_desc.sort_values(ascending=False,inplace=True)

# %%
data_asc.reset_index(drop=True,inplace=True)
data_desc.reset_index(drop=True,inplace=True)
print(data_asc)
print(data_desc)
# Out:
# 0      187
# 1      188
# 2      188
# 3      188
# 4      188
#       ...
# 501    711
# 502    711
# 503    711
# 504    711
# 505    711
# Name: TAX, Length: 506, dtype: int64
# 0      711
# 1      711
# 2      711
# 3      711
# 4      711
#       ...
# 501    188
# 502    188
# 503    188
# 504    188
# 505    187
# Name: TAX, Length: 506, dtype: int64

# %%
data_concat=pd.concat([data_asc,data_desc],axis=1)
data_concat
# Out:
#      TAX  TAX
# 0    187  711
# 1    188  711
# 2    188  711
# 3    188  711
# 4    188  711
# ..   ...  ...
# 501  711  188
# 502  711  188
# 503  711  188
# 504  711  188
# 505  711  187
#
# [506 rows x 2 columns]

# %%
data_concat['diff']=abs(data_concat.iloc[:,0]-data_concat.iloc[:,1])
data_concat
# Out:
#      TAX  TAX  diff
# 0    187  711   524
# 1    188  711   523
# 2    188  711   523
# 3    188  711   523
# 4    188  711   523
# ..   ...  ...   ...
# 501  711  188   523
# 502  711  188   523
# 503  711  188   523
# 504  711  188   523
# 505  711  187   524
#
# [506 rows x 3 columns]

# %%
print(data_concat)
