# %%
import matplotlib.image as img 
import matplotlib.pyplot as pp 
# %matplotlib inline
fileName = "./img/image-20210509230714336.png" 
ndarray = img.imread(fileName) 
pp.rcParams["figure.figsize"] = (30,30)
pp.imshow(ndarray) 
pp.show()

# %%
from sklearn.linear_model import LogisticRegression
import pandas as pd
mtcars = pd.read_csv("./data/mtcars.csv")
print(mtcars.shape)
mtcars.head()
# Out:
# (32, 12)
#           Unnamed: 0   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2

# %%
print(min(mtcars.qsec)) #최소값
print(max(mtcars.qsec)) #최대값
# Out:
# 14.5
# 22.9

# %%
count=0
k=0
for i in mtcars.qsec:
    k=(i-min(mtcars.qsec))/(max(mtcars.qsec)-min(mtcars.qsec))
    if k>0.5:
        count=count+1
        print(i,k) #실제 값 확인
print(count)
# Out:
# 19.44 0.5880952380952383
# 20.22 0.680952380952381
# 20.0 0.6547619047619049
# 22.9 1.0
# 18.9 0.5238095238095237
# 19.47 0.5916666666666667
# 19.9 0.6428571428571428
# 20.01 0.6559523809523813
# 18.9 0.5238095238095237
# 9

# %%
mtcars
# Out:
#              Unnamed: 0   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...

# %%
mtcars['qsecminmax']=(mtcars['qsec']-min(mtcars.qsec))/(max(mtcars.qsec)-min(mtcars.qsec))

# %%
mtcars
# Out:
#              Unnamed: 0   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...

# %%
sum(mtcars['qsecminmax']>0.5)
# Out:
# 9

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
mtcars['qsec']
# Out:
# 0     16.46
# 1     17.02
# 2     18.61
# 3     19.44
# 4     17.02
# 5     20.22
# 6     15.84
# 7     20.00
# 8     22.90
# 9     18.30
# 10    18.90
# 11    17.40
# 12    17.60
# 13    18.00
# 14    17.98
# 15    17.82
# 16    17.42
# 17    19.47
# 18    18.52
# 19    19.90
# 20    20.01
# 21    16.87
# 22    17.30
# 23    15.41
# 24    17.05
# 25    18.90
# 26    16.70
# 27    16.90
# 28    14.50
# 29    15.50
# 30    14.60
# 31    18.60
# Name: qsec, dtype: float64

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
mtcars1=scaler.fit_transform(mtcars['qsec'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-62-f40859ad502a> in <module>
#       1 scaler = MinMaxScaler(feature_range=(0, 1))
# ----> 2 mtcars1=scaler.fit_transform(mtcars['qsec'])
#
# d:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py in fit_transform(self, X, y, **fit_params)
#     569         if y is None:
#     570             # fit method of arity 1 (unsupervised transformation)
# --> 571             return self.fit(X, **fit_params).transform(X)
#     572         else:
#     573             # fit method of arity 2 (supervised transformation)
#
# d:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py in fit(self, X, y)
#     337         # Reset internal state before fitting
#     338         self._reset()
# --> 339         return self.partial_fit(X, y)
#     340
#     341     def partial_fit(self, X, y=None):
#
# ...

# %%
mtcars1
# Out:
# MinMaxScaler(copy=True,
#              feature_range=0     16.46
# 1     17.02
# 2     18.61
# 3     19.44
# 4     17.02
# 5     20.22
# 6     15.84
# 7     20.00
# 8     22.90
# 9     18.30
# 10    18.90
# 11    17.40
# 12    17.60
# 13    18.00
# 14    17.98
# 15    17.82
# 16    17.42
# 17    19.47
# 18    18.52
# 19    19.90
# 20    20.01
# 21    16.87
# 22    17.30
# 23    15.41
# 24    17.05
# 25    18.90
# 26    16.70
# 27    16.90
# 28    14.50
# 29    15.50
# 30    14.60
# 31    18.60
# Name: qsec, dtype: float64)
