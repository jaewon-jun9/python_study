# %%
import pandas as pd
data=pd.read_csv("https://raw.githubusercontent.com/ageron/handson-ml/master/datasets/housing/housing.csv")

# %%
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
data.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
data.shape
# Out:
# (20640, 10)

# %%
data_drop_na=data.dropna(axis=0)

# %%
data_drop_na.shape
# Out:
# (20433, 10)

# %%
data_70=data_drop_na.head(int(20433*0.7))
data_70
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 14436    -117.24     32.80                28.0       1072.0           331.0
# 14437    -117.24     32.80                18.0       2205.0           661.0
# 14438    -117.24     32.80                19.0       1863.0           497.0
# 14439    -117.24     32.80                30.0       1917.0           462.0
# 14440    -117.24     32.80                29.0       3376.0           882.0
#
# ...

# %%
data_70.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  14303.000000  14303.000000        14303.000000  14303.000000
# mean    -119.118076     35.286336           29.263092   2621.442005
# std        1.833372      2.026415           12.403161   2268.391045
# min     -124.350000     32.660000            1.000000      2.000000
# 25%     -120.790000     33.910000           19.000000   1419.000000
# 50%     -118.310000     34.100000           30.000000   2073.000000
# 75%     -117.960000     37.400000           38.000000   3080.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    14303.000000  14303.000000  14303.000000   14303.000000
# mean       541.475634   1436.816262    500.118856       3.786819
# std        437.156447   1142.531705    393.666809       1.895931
# min          2.000000      3.000000      2.000000       0.499900
# ...

# %%
data_70['housing_median_age'].quantile(.25)
# Out:
# 19.0

# %%
titanic=pd.read_csv("./data/train.csv")

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
train = pd.DataFrame(titanic.isnull().sum(), columns = ['null_sum'])

# %%
train
# Out:
#              null_sum
# PassengerId         0
# Survived            0
# Pclass              0
# Name                0
# Sex                 0
# Age               177
# SibSp               0
# Parch               0
# Ticket              0
# Fare                0
# Cabin             687
# Embarked            2

# %%
train.reset_index(inplace = True)
result = train[train['null_sum'] == train['null_sum'].max()]['index'].reset_index(drop = True)[0]
print(result)
# Out:
# Cabin

# %%
print(train[train['null_sum'] == train['null_sum'].max()]['index'].reset_index(drop = True)[0])
# Out:
# Cabin

# %%
# Out:
#     index  null_sum
# 10  Cabin       687
