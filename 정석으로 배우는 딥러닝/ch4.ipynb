# %%
import numpy as np
from keras.models import Sequential
from keras.layers.core import Dense, Activation
from keras.optimizers import SGD
from sklearn.datasets import fetch_openml
from sklearn.model_selection import train_test_split

np.random.seed(0)

'''
데이터를 생성한다
'''
mnist = fetch_openml('mnist_784')

n = len(mnist.data)
N = 10000  # MNIST의 일부를 사용한다
indices = np.random.permutation(range(n))[:N]  # 무작위로 N장을 선택

X = mnist.data[indices]
y = mnist.target[indices]
Y = np.eye(10)[y.astype(int)]  # 1-of-K 표현으로 변환한다

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, train_size=0.8)

'''
모델을 설정한다
'''
n_in = len(X[0])  # 784
n_hidden = 200
# n_hidden = 4000
n_out = len(Y[0])  # 10

model = Sequential()
model.add(Dense(n_hidden, input_dim=n_in))
model.add(Activation('sigmoid'))

# model.add(Dense(n_hidden))
# model.add(Activation('sigmoid'))

# model.add(Dense(n_hidden))
# model.add(Activation('sigmoid'))

# model.add(Dense(n_hidden))
# model.add(Activation('sigmoid'))

model.add(Dense(n_out))
model.add(Activation('softmax'))

model.compile(loss='categorical_crossentropy',
              optimizer=SGD(lr=0.01),
              metrics=['accuracy'])

'''
모델을 학습시킨다
'''
epochs = 100
batch_size = 200

model.fit(X_train, Y_train, epochs=epochs, batch_size=batch_size)

'''
예측 정확도를 평가한다
'''
loss_and_metrics = model.evaluate(X_test, Y_test)
print(loss_and_metrics)
# Out:
# Epoch 1/100
# 40/40 [==============================] - 0s 3ms/step - loss: 1.9083 - accuracy: 0.3720
# Epoch 2/100
# 40/40 [==============================] - 0s 2ms/step - loss: 1.2966 - accuracy: 0.6724
# Epoch 3/100
# 40/40 [==============================] - 0s 2ms/step - loss: 1.0347 - accuracy: 0.7611
# Epoch 4/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.8788 - accuracy: 0.8045
# Epoch 5/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.7785 - accuracy: 0.8300
# Epoch 6/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.7009 - accuracy: 0.8471
# Epoch 7/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.6412 - accuracy: 0.8635
# Epoch 8/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.5953 - accuracy: 0.8758
# Epoch 9/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.5591 - accuracy: 0.8810
# Epoch 10/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.5258 - accuracy: 0.8874
# Epoch 11/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.4993 - accuracy: 0.8938
# Epoch 12/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.4748 - accuracy: 0.9003
# Epoch 13/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.4552 - accuracy: 0.9039
# Epoch 14/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.4363 - accuracy: 0.9062
# Epoch 15/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.4188 - accuracy: 0.9149
# Epoch 16/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.4031 - accuracy: 0.9176
# Epoch 17/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.3894 - accuracy: 0.9209
# Epoch 18/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.3757 - accuracy: 0.9233
# Epoch 19/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.3644 - accuracy: 0.9262
# Epoch 20/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.3540 - accuracy: 0.9286
# Epoch 21/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.3435 - accuracy: 0.9298
# Epoch 22/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.3347 - accuracy: 0.9331
# Epoch 23/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.3252 - accuracy: 0.9339
# Epoch 24/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.3178 - accuracy: 0.9336
# Epoch 25/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.3126 - accuracy: 0.9345
# Epoch 26/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.3047 - accuracy: 0.9371
# Epoch 27/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.2979 - accuracy: 0.9399
# Epoch 28/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.2911 - accuracy: 0.9409
# Epoch 29/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.2849 - accuracy: 0.9416
# Epoch 30/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.2795 - accuracy: 0.9433
# Epoch 31/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.2745 - accuracy: 0.9439
# Epoch 32/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.2695 - accuracy: 0.9454
# Epoch 33/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.2651 - accuracy: 0.9464
# Epoch 34/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.2600 - accuracy: 0.9484
# Epoch 35/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.2559 - accuracy: 0.9477
# Epoch 36/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.2525 - accuracy: 0.9479
# Epoch 37/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.2484 - accuracy: 0.9485
# Epoch 38/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.2451 - accuracy: 0.9495
# Epoch 39/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.2417 - accuracy: 0.9501
# Epoch 40/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.2385 - accuracy: 0.9510
# Epoch 41/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.2355 - accuracy: 0.9517
# Epoch 42/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.2326 - accuracy: 0.9517
# Epoch 43/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.2299 - accuracy: 0.9526
# Epoch 44/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.2271 - accuracy: 0.9531
# Epoch 45/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.2251 - accuracy: 0.9532
# Epoch 46/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.2226 - accuracy: 0.9550
# Epoch 47/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.2203 - accuracy: 0.9546
# Epoch 48/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.2177 - accuracy: 0.9559
# Epoch 49/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.2160 - accuracy: 0.9555
# Epoch 50/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.2136 - accuracy: 0.9555
# Epoch 51/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.2114 - accuracy: 0.9563
# Epoch 52/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.2098 - accuracy: 0.9557
# Epoch 53/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.2075 - accuracy: 0.9565
# Epoch 54/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.2059 - accuracy: 0.9567
# Epoch 55/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.2045 - accuracy: 0.9563
# Epoch 56/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.2025 - accuracy: 0.9569
# Epoch 57/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.2007 - accuracy: 0.9566
# Epoch 58/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.1991 - accuracy: 0.9576
# Epoch 59/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.1972 - accuracy: 0.9581
# Epoch 60/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.1955 - accuracy: 0.9588
# Epoch 61/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.1943 - accuracy: 0.9582
# Epoch 62/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.1932 - accuracy: 0.9585
# Epoch 63/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.1915 - accuracy: 0.9594
# Epoch 64/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.1901 - accuracy: 0.9592
# Epoch 65/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.1888 - accuracy: 0.9595
# Epoch 66/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.1876 - accuracy: 0.9600
# Epoch 67/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.1864 - accuracy: 0.9597
# Epoch 68/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.1853 - accuracy: 0.9601
# Epoch 69/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.1839 - accuracy: 0.9604
# Epoch 70/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.1828 - accuracy: 0.9605
# Epoch 71/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.1817 - accuracy: 0.9609
# Epoch 72/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.1806 - accuracy: 0.9609
# Epoch 73/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.1795 - accuracy: 0.9607
# Epoch 74/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.1786 - accuracy: 0.9611
# Epoch 75/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.1774 - accuracy: 0.9610
# Epoch 76/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.1765 - accuracy: 0.9614
# Epoch 77/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.1754 - accuracy: 0.9614
# Epoch 78/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.1745 - accuracy: 0.9613
# Epoch 79/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.1737 - accuracy: 0.9614
# Epoch 80/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.1728 - accuracy: 0.9614
# Epoch 81/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.1719 - accuracy: 0.9614
# Epoch 82/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.1710 - accuracy: 0.9615
# Epoch 83/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.1702 - accuracy: 0.9616
# Epoch 84/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.1694 - accuracy: 0.9620
# Epoch 85/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.1686 - accuracy: 0.9619
# Epoch 86/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.1679 - accuracy: 0.9620
# Epoch 87/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.1670 - accuracy: 0.9621
# Epoch 88/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.1662 - accuracy: 0.9619
# Epoch 89/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.1655 - accuracy: 0.9620
# Epoch 90/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.1647 - accuracy: 0.9622
# Epoch 91/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.1640 - accuracy: 0.9624
# Epoch 92/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.1633 - accuracy: 0.9625
# Epoch 93/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.1627 - accuracy: 0.9628
# Epoch 94/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.1623 - accuracy: 0.9629
# Epoch 95/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.1615 - accuracy: 0.9631
# Epoch 96/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.1609 - accuracy: 0.9631
# Epoch 97/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.1599 - accuracy: 0.9635
# Epoch 98/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.1593 - accuracy: 0.9631
# Epoch 99/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.1585 - accuracy: 0.9636
# Epoch 100/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.1579 - accuracy: 0.9639
# 63/63 [==============================] - 0s 724us/step - loss: 0.3720 - accuracy: 0.8875
# [0.3720274567604065, 0.887499988079071]

# %%
from sklearn import datasets
datasets.get_data_home()
# Out:
# 'C:\\Users\\upnell\\scikit_learn_data'

# %%
import numpy as np
from keras.models import Sequential
from keras.layers.core import Dense, Activation
from keras.optimizers import SGD
from sklearn.datasets import fetch_openml
from sklearn.model_selection import train_test_split

np.random.seed(0)

'''
데이터를 생성한다
'''
mnist = fetch_openml('mnist_784')


n = len(mnist.data)
N = 10000  # MNIST의 일부를 사용한다
indices = np.random.permutation(range(n))[:N]  # 무작위로 N장을 선택

X = mnist.data[indices]
y = mnist.target[indices]
Y = np.eye(10)[y.astype(int)]  # 1-of-K 표현으로 변환한다

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, train_size=0.8)

'''
모델을 설정한다
'''
n_in = len(X[0])  # 784
n_hidden = 200
n_out = len(Y[0])  # 10

model = Sequential()
model.add(Dense(n_hidden, input_dim=n_in))
model.add(Activation('tanh'))

model.add(Dense(n_hidden))
model.add(Activation('tanh'))

model.add(Dense(n_hidden))
model.add(Activation('tanh'))

model.add(Dense(n_hidden))
model.add(Activation('tanh'))

model.add(Dense(n_out))
model.add(Activation('softmax'))

model.compile(loss='categorical_crossentropy',
              optimizer=SGD(lr=0.01),
              metrics=['accuracy'])

'''
모델을 학습시킨다
'''
epochs = 100
batch_size = 200

model.fit(X_train, Y_train, epochs=epochs, batch_size=batch_size)

'''
예측 정확도를 평가한다
'''
loss_and_metrics = model.evaluate(X_test, Y_test)
print(loss_and_metrics)
# Out:
# Epoch 1/100
# 40/40 [==============================] - 0s 4ms/step - loss: 1.8769 - accuracy: 0.3966
# Epoch 2/100
# 40/40 [==============================] - 0s 4ms/step - loss: 1.2205 - accuracy: 0.6925
# Epoch 3/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.9168 - accuracy: 0.7705
# Epoch 4/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.7491 - accuracy: 0.8119
# Epoch 5/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.6414 - accuracy: 0.8345
# Epoch 6/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.5701 - accuracy: 0.8474
# Epoch 7/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.5182 - accuracy: 0.8627
# Epoch 8/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.4801 - accuracy: 0.8696
# Epoch 9/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.4454 - accuracy: 0.8819
# Epoch 10/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.4161 - accuracy: 0.8859
# Epoch 11/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.3894 - accuracy: 0.8974
# Epoch 12/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.3709 - accuracy: 0.9015
# Epoch 13/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.3528 - accuracy: 0.9053
# Epoch 14/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.3441 - accuracy: 0.9074
# Epoch 15/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.3251 - accuracy: 0.9110
# Epoch 16/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.3156 - accuracy: 0.9147
# Epoch 17/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.3022 - accuracy: 0.9176
# Epoch 18/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.2924 - accuracy: 0.9186
# Epoch 19/100
# 40/40 [==============================] - 0s 5ms/step - loss: 0.2807 - accuracy: 0.9233
# Epoch 20/100
# 40/40 [==============================] - 0s 5ms/step - loss: 0.2728 - accuracy: 0.9275
# Epoch 21/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.2648 - accuracy: 0.9270
# Epoch 22/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.2581 - accuracy: 0.9304
# Epoch 23/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.2444 - accuracy: 0.9324
# Epoch 24/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.2354 - accuracy: 0.9333
# Epoch 25/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.2317 - accuracy: 0.9356
# Epoch 26/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.2217 - accuracy: 0.9396
# Epoch 27/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.2184 - accuracy: 0.9414
# Epoch 28/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.2161 - accuracy: 0.9417
# Epoch 29/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.2081 - accuracy: 0.9448
# Epoch 30/100
# 40/40 [==============================] - 0s 5ms/step - loss: 0.2006 - accuracy: 0.9471
# Epoch 31/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.1951 - accuracy: 0.9482
# Epoch 32/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.1861 - accuracy: 0.9520
# Epoch 33/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.1852 - accuracy: 0.9504
# Epoch 34/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.1901 - accuracy: 0.9485
# Epoch 35/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.1861 - accuracy: 0.9523
# Epoch 36/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.1767 - accuracy: 0.9520
# Epoch 37/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.1738 - accuracy: 0.9536
# Epoch 38/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.1715 - accuracy: 0.9551
# Epoch 39/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.1704 - accuracy: 0.9545
# Epoch 40/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.1624 - accuracy: 0.9588
# Epoch 41/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.1539 - accuracy: 0.9610
# Epoch 42/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.1551 - accuracy: 0.9592
# Epoch 43/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.1484 - accuracy: 0.9614
# Epoch 44/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.1441 - accuracy: 0.9614
# Epoch 45/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.1337 - accuracy: 0.9645
# Epoch 46/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.1277 - accuracy: 0.9647
# Epoch 47/100
# 40/40 [==============================] - 0s 5ms/step - loss: 0.1300 - accuracy: 0.9684
# Epoch 48/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.1257 - accuracy: 0.9691
# Epoch 49/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.1188 - accuracy: 0.9691
# Epoch 50/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.1209 - accuracy: 0.9712
# Epoch 51/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.1176 - accuracy: 0.9711
# Epoch 52/100
# 40/40 [==============================] - 0s 5ms/step - loss: 0.1114 - accuracy: 0.9739
# Epoch 53/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.1065 - accuracy: 0.9755
# Epoch 54/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.1017 - accuracy: 0.9778
# Epoch 55/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.1035 - accuracy: 0.9745
# Epoch 56/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.1016 - accuracy: 0.9764
# Epoch 57/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0971 - accuracy: 0.9761
# Epoch 58/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0952 - accuracy: 0.9766
# Epoch 59/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0929 - accuracy: 0.9790
# Epoch 60/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0904 - accuracy: 0.9789
# Epoch 61/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0889 - accuracy: 0.9797
# Epoch 62/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0943 - accuracy: 0.9774
# Epoch 63/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0904 - accuracy: 0.9781
# Epoch 64/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0830 - accuracy: 0.9806
# Epoch 65/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0805 - accuracy: 0.9820
# Epoch 66/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0842 - accuracy: 0.9808
# Epoch 67/100
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0792 - accuracy: 0.9829
# Epoch 68/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0776 - accuracy: 0.9833
# Epoch 69/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0792 - accuracy: 0.9827
# Epoch 70/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0746 - accuracy: 0.9833
# Epoch 71/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0748 - accuracy: 0.9830
# Epoch 72/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0735 - accuracy: 0.9839
# Epoch 73/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0700 - accuracy: 0.9847
# Epoch 74/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0657 - accuracy: 0.9854
# Epoch 75/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0608 - accuracy: 0.9876
# Epoch 76/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0578 - accuracy: 0.9891
# Epoch 77/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0597 - accuracy: 0.9879
# Epoch 78/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0600 - accuracy: 0.9869
# Epoch 79/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0547 - accuracy: 0.9896
# Epoch 80/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0547 - accuracy: 0.9887
# Epoch 81/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0552 - accuracy: 0.9890
# Epoch 82/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0507 - accuracy: 0.9902
# Epoch 83/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0499 - accuracy: 0.9912
# Epoch 84/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0474 - accuracy: 0.9906
# Epoch 85/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0453 - accuracy: 0.9919
# Epoch 86/100
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0441 - accuracy: 0.9924
# Epoch 87/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0438 - accuracy: 0.9921
# Epoch 88/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0417 - accuracy: 0.9926
# Epoch 89/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0406 - accuracy: 0.9926
# Epoch 90/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0375 - accuracy: 0.9931
# Epoch 91/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0353 - accuracy: 0.9940
# Epoch 92/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0340 - accuracy: 0.9944
# Epoch 93/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0341 - accuracy: 0.9940
# Epoch 94/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0325 - accuracy: 0.9946
# Epoch 95/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0314 - accuracy: 0.9952
# Epoch 96/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0315 - accuracy: 0.9950
# Epoch 97/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0309 - accuracy: 0.9950
# Epoch 98/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0301 - accuracy: 0.9948
# Epoch 99/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0290 - accuracy: 0.9950
# Epoch 100/100
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0280 - accuracy: 0.9949
# 63/63 [==============================] - 0s 1ms/step - loss: 0.3036 - accuracy: 0.9115
# [0.30357369780540466, 0.9114999771118164]

# %%
import numpy as np
from keras.models import Sequential
from keras.layers.core import Dense, Activation
from keras.optimizers import SGD
from sklearn.datasets import fetch_openml
from sklearn.model_selection import train_test_split

np.random.seed(1234)

'''
데이터를 생성한다
'''
#mnist = datasets.fetch_mldata('MNIST original', data_home='./')
mnist = fetch_openml('mnist_784')

n = len(mnist.data)
N = 10000  # MNIST의 일부를 사용한다
indices = np.random.permutation(range(n))[:N]  # 무작위로 N장을 선택

X = mnist.data[indices]
y = mnist.target[indices]
Y = np.eye(10)[y.astype(int)]  # 1-of-K 표현으로 변환한다

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, train_size=0.8)

'''
모델을 설정한다
'''
n_in = len(X[0])  # 784
n_hidden = 200
n_out = len(Y[0])  # 10

model = Sequential()
model.add(Dense(n_hidden, input_dim=n_in))
model.add(Activation('relu'))

model.add(Dense(n_hidden))
model.add(Activation('relu'))

model.add(Dense(n_hidden))
model.add(Activation('relu'))

model.add(Dense(n_hidden))
model.add(Activation('relu'))

model.add(Dense(n_out))
model.add(Activation('softmax'))

model.compile(loss='categorical_crossentropy',
              optimizer=SGD(lr=0.01),
              metrics=['accuracy'])

'''
모델을 학습시킨다
'''
# epochs = 100
epochs = 50  # ReLU를 사용하면 학습이 빨리 끝난다
batch_size = 200

model.fit(X_train, Y_train, epochs=epochs, batch_size=batch_size)

'''
예측 정확도를 평가한다
'''
loss_and_metrics = model.evaluate(X_test, Y_test)
print(loss_and_metrics)
# Out:
# Epoch 1/50
# 40/40 [==============================] - 0s 12ms/step - loss: nan - accuracy: 0.0949
# Epoch 2/50
# 40/40 [==============================] - 0s 10ms/step - loss: nan - accuracy: 0.0971
# Epoch 3/50
# 40/40 [==============================] - 0s 11ms/step - loss: nan - accuracy: 0.0971
# Epoch 4/50
# 40/40 [==============================] - 1s 13ms/step - loss: nan - accuracy: 0.0971
# Epoch 5/50
# 40/40 [==============================] - 0s 12ms/step - loss: nan - accuracy: 0.0971
# Epoch 6/50
# 40/40 [==============================] - 0s 12ms/step - loss: nan - accuracy: 0.0971
# Epoch 7/50
# 40/40 [==============================] - 0s 10ms/step - loss: nan - accuracy: 0.0971
# Epoch 8/50
# 40/40 [==============================] - 0s 12ms/step - loss: nan - accuracy: 0.0971: 0s - loss: nan - accuracy: 0.09
# Epoch 9/50
# 40/40 [==============================] - 0s 12ms/step - loss: nan - accuracy: 0.0971
# Epoch 10/50
# 40/40 [==============================] - 0s 12ms/step - loss: nan - accuracy: 0.0971
# Epoch 11/50
# 40/40 [==============================] - 1s 13ms/step - loss: nan - accuracy: 0.0971
# Epoch 12/50
# 40/40 [==============================] - 1s 14ms/step - loss: nan - accuracy: 0.0971
# Epoch 13/50
# 40/40 [==============================] - 1s 13ms/step - loss: nan - accuracy: 0.0971
# Epoch 14/50
# 40/40 [==============================] - 0s 12ms/step - loss: nan - accuracy: 0.0971
# Epoch 15/50
# 40/40 [==============================] - 0s 11ms/step - loss: nan - accuracy: 0.0971
# Epoch 16/50
# 40/40 [==============================] - 0s 12ms/step - loss: nan - accuracy: 0.0971
# Epoch 17/50
# 40/40 [==============================] - 0s 12ms/step - loss: nan - accuracy: 0.0971
# Epoch 18/50
# 40/40 [==============================] - 0s 12ms/step - loss: nan - accuracy: 0.0971
# Epoch 19/50
# 40/40 [==============================] - 0s 12ms/step - loss: nan - accuracy: 0.0971
# Epoch 20/50
# 40/40 [==============================] - 0s 12ms/step - loss: nan - accuracy: 0.0971
# Epoch 21/50
# 40/40 [==============================] - 0s 12ms/step - loss: nan - accuracy: 0.0971
# Epoch 22/50
# 40/40 [==============================] - 1s 13ms/step - loss: nan - accuracy: 0.0971
# Epoch 23/50
# 40/40 [==============================] - 0s 12ms/step - loss: nan - accuracy: 0.0971
# Epoch 24/50
# 40/40 [==============================] - 0s 12ms/step - loss: nan - accuracy: 0.0971
# Epoch 25/50
# 40/40 [==============================] - 0s 12ms/step - loss: nan - accuracy: 0.0971
# Epoch 26/50
# 40/40 [==============================] - 0s 12ms/step - loss: nan - accuracy: 0.0971
# Epoch 27/50
# 40/40 [==============================] - 0s 12ms/step - loss: nan - accuracy: 0.0971
# Epoch 28/50
# 40/40 [==============================] - 0s 11ms/step - loss: nan - accuracy: 0.0971
# Epoch 29/50
# 40/40 [==============================] - 0s 12ms/step - loss: nan - accuracy: 0.0971
# Epoch 30/50
# 40/40 [==============================] - 1s 13ms/step - loss: nan - accuracy: 0.0971
# Epoch 31/50
# 40/40 [==============================] - 1s 13ms/step - loss: nan - accuracy: 0.0971
# Epoch 32/50
# 40/40 [==============================] - 0s 10ms/step - loss: nan - accuracy: 0.0971
# Epoch 33/50
# 40/40 [==============================] - 1s 13ms/step - loss: nan - accuracy: 0.0971
# Epoch 34/50
# 40/40 [==============================] - 1s 13ms/step - loss: nan - accuracy: 0.0971
# Epoch 35/50
# 40/40 [==============================] - 1s 13ms/step - loss: nan - accuracy: 0.0971
# Epoch 36/50
# 40/40 [==============================] - 0s 12ms/step - loss: nan - accuracy: 0.0971
# Epoch 37/50
# 40/40 [==============================] - 1s 13ms/step - loss: nan - accuracy: 0.0971
# Epoch 38/50
# 40/40 [==============================] - 1s 13ms/step - loss: nan - accuracy: 0.0971
# Epoch 39/50
# 40/40 [==============================] - 0s 11ms/step - loss: nan - accuracy: 0.0971
# Epoch 40/50
# 40/40 [==============================] - 0s 11ms/step - loss: nan - accuracy: 0.0971
# Epoch 41/50
# 40/40 [==============================] - 0s 12ms/step - loss: nan - accuracy: 0.0971
# Epoch 42/50
# 40/40 [==============================] - 0s 12ms/step - loss: nan - accuracy: 0.0971
# Epoch 43/50
# 40/40 [==============================] - 0s 11ms/step - loss: nan - accuracy: 0.0971
# Epoch 44/50
# 40/40 [==============================] - 0s 11ms/step - loss: nan - accuracy: 0.0971
# Epoch 45/50
# 40/40 [==============================] - 1s 13ms/step - loss: nan - accuracy: 0.0971
# Epoch 46/50
# 40/40 [==============================] - 0s 11ms/step - loss: nan - accuracy: 0.0971
# Epoch 47/50
# 40/40 [==============================] - 0s 12ms/step - loss: nan - accuracy: 0.0971: 0s - loss: nan - accuracy:
# Epoch 48/50
# 40/40 [==============================] - 0s 12ms/step - loss: nan - accuracy: 0.0971
# Epoch 49/50
# 40/40 [==============================] - 0s 11ms/step - loss: nan - accuracy: 0.0971
# Epoch 50/50
# 40/40 [==============================] - 0s 12ms/step - loss: nan - accuracy: 0.0971
# 63/63 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.0855
# [nan, 0.08550000190734863]

# %%
import numpy as np
from keras.models import Sequential
from keras.layers.core import Dense, Activation
from keras.layers.advanced_activations import LeakyReLU
from keras.optimizers import SGD
from sklearn import datasets
from sklearn.model_selection import train_test_split

np.random.seed(1234)

'''
데이터를 생성한다
'''
mnist = datasets.fetch_openml('mnist_784')

n = len(mnist.data)
N = 10000  # MNIST의 일부를 사용한다
indices = np.random.permutation(range(n))[:N]  # 무작위로 N장을 선택

X = mnist.data[indices]
y = mnist.target[indices]
Y = np.eye(10)[y.astype(int)]  # 1-of-K 표현으로 변환한다

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, train_size=0.8)

'''
모델을 설정한다
'''
n_in = len(X[0])  # 784
n_hidden = 200
n_out = len(Y[0])  # 10

alpha = 0.01

model = Sequential()
model.add(Dense(n_hidden, input_dim=n_in))
model.add(LeakyReLU(alpha=alpha))

model.add(Dense(n_hidden))
model.add(LeakyReLU(alpha=alpha))

model.add(Dense(n_hidden))
model.add(LeakyReLU(alpha=alpha))

model.add(Dense(n_hidden))
model.add(LeakyReLU(alpha=alpha))

model.add(Dense(n_out))
model.add(Activation('softmax'))

model.compile(loss='categorical_crossentropy',
              optimizer=SGD(lr=0.01),
              metrics=['accuracy'])

'''
모델을 학습시킨다
'''
epochs = 20
batch_size = 200

model.fit(X_train, Y_train, epochs=epochs, batch_size=batch_size)

'''
예측 정확도를 평가한다
'''
loss_and_metrics = model.evaluate(X_test, Y_test)
print(loss_and_metrics)
# Out:
# Epoch 1/20
# 40/40 [==============================] - 0s 11ms/step - loss: nan - accuracy: 0.0969
# Epoch 2/20
# 40/40 [==============================] - 1s 15ms/step - loss: nan - accuracy: 0.0971
# Epoch 3/20
# 40/40 [==============================] - 0s 12ms/step - loss: nan - accuracy: 0.0971
# Epoch 4/20
# 40/40 [==============================] - 0s 12ms/step - loss: nan - accuracy: 0.0971
# Epoch 5/20
# 40/40 [==============================] - 0s 12ms/step - loss: nan - accuracy: 0.0971
# Epoch 6/20
# 40/40 [==============================] - 1s 13ms/step - loss: nan - accuracy: 0.0971
# Epoch 7/20
# 40/40 [==============================] - 0s 11ms/step - loss: nan - accuracy: 0.0971
# Epoch 8/20
# 40/40 [==============================] - 0s 12ms/step - loss: nan - accuracy: 0.0971
# Epoch 9/20
# 40/40 [==============================] - 1s 14ms/step - loss: nan - accuracy: 0.0971
# Epoch 10/20
# 40/40 [==============================] - 0s 11ms/step - loss: nan - accuracy: 0.0971
# Epoch 11/20
# 40/40 [==============================] - 0s 11ms/step - loss: nan - accuracy: 0.0971
# Epoch 12/20
# 40/40 [==============================] - 0s 12ms/step - loss: nan - accuracy: 0.0971
# Epoch 13/20
# 40/40 [==============================] - 0s 12ms/step - loss: nan - accuracy: 0.0971
# Epoch 14/20
# 40/40 [==============================] - 1s 13ms/step - loss: nan - accuracy: 0.0971
# Epoch 15/20
# 40/40 [==============================] - 1s 13ms/step - loss: nan - accuracy: 0.0971
# Epoch 16/20
# 40/40 [==============================] - 0s 11ms/step - loss: nan - accuracy: 0.0971
# Epoch 17/20
# 40/40 [==============================] - 1s 13ms/step - loss: nan - accuracy: 0.0971
# Epoch 18/20
# 40/40 [==============================] - 1s 13ms/step - loss: nan - accuracy: 0.0971
# Epoch 19/20
# 40/40 [==============================] - 0s 12ms/step - loss: nan - accuracy: 0.0971
# Epoch 20/20
# 40/40 [==============================] - 0s 12ms/step - loss: nan - accuracy: 0.0971
# 63/63 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.0855
# [nan, 0.08550000190734863]

# %%
import numpy as np
from keras.models import Sequential
from keras.layers.core import Dense, Activation
from keras.layers.advanced_activations import PReLU
from keras.optimizers import SGD
from sklearn import datasets
from sklearn.model_selection import train_test_split

np.random.seed(123)

'''
데이터를 생성한다
'''
mnist = datasets.fetch_openml('mnist_784')

n = len(mnist.data)
N = 10000  # MNIST의 일부를 사용한다
indices = np.random.permutation(range(n))[:N]  # 무작위로 N장을 선택

X = mnist.data[indices]
y = mnist.target[indices]
Y = np.eye(10)[y.astype(int)]  # 1-of-K 표현으로 변환한다

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, train_size=0.8)

'''
모델을 설정한다
'''
n_in = len(X[0])  # 784
n_hidden = 200
n_out = len(Y[0])  # 10

model = Sequential()
model.add(Dense(n_hidden, input_dim=n_in))
model.add(PReLU())

model.add(Dense(n_hidden))
model.add(PReLU())

model.add(Dense(n_hidden))
model.add(PReLU())

model.add(Dense(n_hidden))
model.add(PReLU())

model.add(Dense(n_out))
model.add(Activation('softmax'))

model.compile(loss='categorical_crossentropy',
              optimizer=SGD(lr=0.01),
              metrics=['accuracy'])

'''
모델을 학습시킨다
'''
epochs = 20
batch_size = 200

model.fit(X_train, Y_train, epochs=epochs, batch_size=batch_size)

'''
예측 정확도를 평가한다
'''
loss_and_metrics = model.evaluate(X_test, Y_test)
print(loss_and_metrics)
# Out:
# Epoch 1/20
# 40/40 [==============================] - 1s 14ms/step - loss: nan - accuracy: 0.1020
# Epoch 2/20
# 40/40 [==============================] - 1s 14ms/step - loss: nan - accuracy: 0.0995
# Epoch 3/20
# 40/40 [==============================] - 0s 12ms/step - loss: nan - accuracy: 0.0995
# Epoch 4/20
# 40/40 [==============================] - 1s 13ms/step - loss: nan - accuracy: 0.0995
# Epoch 5/20
# 40/40 [==============================] - 0s 12ms/step - loss: nan - accuracy: 0.0995
# Epoch 6/20
# 40/40 [==============================] - 1s 13ms/step - loss: nan - accuracy: 0.0995
# Epoch 7/20
# 40/40 [==============================] - 1s 14ms/step - loss: nan - accuracy: 0.0995
# Epoch 8/20
# 40/40 [==============================] - 0s 12ms/step - loss: nan - accuracy: 0.0995
# Epoch 9/20
# 40/40 [==============================] - 0s 12ms/step - loss: nan - accuracy: 0.0995
# Epoch 10/20
# 40/40 [==============================] - 1s 14ms/step - loss: nan - accuracy: 0.0995
# Epoch 11/20
# 40/40 [==============================] - 1s 13ms/step - loss: nan - accuracy: 0.0995
# Epoch 12/20
# 40/40 [==============================] - 1s 13ms/step - loss: nan - accuracy: 0.0995
# Epoch 13/20
# 40/40 [==============================] - 1s 14ms/step - loss: nan - accuracy: 0.0995
# Epoch 14/20
# 40/40 [==============================] - 1s 13ms/step - loss: nan - accuracy: 0.0995
# Epoch 15/20
# 40/40 [==============================] - 1s 14ms/step - loss: nan - accuracy: 0.0995
# Epoch 16/20
# 40/40 [==============================] - 1s 13ms/step - loss: nan - accuracy: 0.0995
# Epoch 17/20
# 40/40 [==============================] - 0s 12ms/step - loss: nan - accuracy: 0.0995
# Epoch 18/20
# 40/40 [==============================] - 1s 13ms/step - loss: nan - accuracy: 0.0995
# Epoch 19/20
# 40/40 [==============================] - 1s 13ms/step - loss: nan - accuracy: 0.0995
# Epoch 20/20
# 40/40 [==============================] - 1s 13ms/step - loss: nan - accuracy: 0.0995
# 63/63 [==============================] - 0s 3ms/step - loss: nan - accuracy: 0.0940
# [nan, 0.09399999678134918]

# %%
import numpy as np
from keras.models import Sequential
from keras.layers.core import Dense, Activation, Dropout
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping
from sklearn import datasets
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

np.random.seed(123)

'''
데이터를 생성한다
'''
mnist = datasets.fetch_openml('mnist_784')

n = len(mnist.data)
N = 30000  # MNIST의 일부를 사용한다
N_train = 20000
N_validation = 4000
indices = np.random.permutation(range(n))[:N]  # 무작위로 N장을 선택한다

X = mnist.data[indices]
X = X / 255.0
X = X - X.mean(axis=1).reshape(len(X), 1)
y = mnist.target[indices]
Y = np.eye(10)[y.astype(int)]

X_train, X_test, Y_train, Y_test = \
    train_test_split(X, Y, train_size=N_train)
X_train, X_validation, Y_train, Y_validation = \
    train_test_split(X_train, Y_train, test_size=N_validation)

'''
모델을 설정한다
'''
n_in = len(X[0])  # 784
n_hiddens = [200, 200, 200]
n_out = len(Y[0])  # 10
p_keep = 0.5
activation = 'relu'


def weight_variable(shape, name=None):
    return np.sqrt(2.0 / shape[0]) * np.random.normal(size=shape)


early_stopping = EarlyStopping(monitor='val_loss', patience=10, verbose=1)

model = Sequential()
for i, input_dim in enumerate(([n_in] + n_hiddens)[:-1]):
    model.add(Dense(n_hiddens[i], input_dim=input_dim,
                    kernel_initializer=weight_variable))
    model.add(Activation(activation))
    model.add(Dropout(p_keep))

model.add(Dense(n_out, kernel_initializer=weight_variable))
model.add(Activation('softmax'))

model.compile(loss='categorical_crossentropy',
              optimizer=Adam(lr=0.001, beta_1=0.9, beta_2=0.999),
              metrics=['accuracy'])

'''
모델을 학습시킨다
'''
epochs = 200
batch_size = 200

hist = model.fit(X_train, Y_train, epochs=epochs,
                 batch_size=batch_size,
                 validation_data=(X_validation, Y_validation),
                 callbacks=[early_stopping])

'''
학습이 진행되는 상황을 가시화한다
'''
val_acc = hist.history['val_acc']
val_loss = hist.history['val_loss']

plt.rc('font', family='serif')
fig = plt.figure()
plt.plot(range(len(val_loss)), val_loss, label='loss', color='black')
plt.xlabel('epochs')
plt.show()

'''
예측 정확도를 평가한다
'''
loss_and_metrics = model.evaluate(X_test, Y_test)
print(loss_and_metrics)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-2933dd5a7ee5> in <module>
#      51 for i, input_dim in enumerate(([n_in] + n_hiddens)[:-1]):
#      52     model.add(Dense(n_hiddens[i], input_dim=input_dim,
# ---> 53                     kernel_initializer=weight_variable))
#      54     model.add(Activation(activation))
#      55     model.add(Dropout(p_keep))
#
# d:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\training\tracking\base.py in _method_wrapper(self, *args, **kwargs)
#     455     self._self_setattr_tracking = False  # pylint: disable=protected-access
#     456     try:
# --> 457       result = method(self, *args, **kwargs)
#     458     finally:
#     459       self._self_setattr_tracking = previous_value  # pylint: disable=protected-access
#
# d:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\sequential.py in add(self, layer)
#     204           # and create the node connecting the current layer
#     205           # to the input layer we just created.
# --> 206           layer(x)
#     207           set_inputs = True
#     208
#
# d:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\base_layer.py in __call__(self, *args, **kwargs)
#     924     if _in_functional_construction_mode(self, inputs, args, kwargs, input_list):
#     925       return self._functional_construction_call(inputs, args, kwargs,
# --> 926                                                 input_list)
#     927
#     928     # Maintains info about the `Layer.call` stack.
#
# d:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\base_layer.py in _functional_construction_call(self, inputs, args, kwargs, input_list)
#    1096         # Build layer if applicable (if the `build` method has been
#    1097         # overridden).
# -> 1098         self._maybe_build(inputs)
#    1099         cast_inputs = self._maybe_cast_inputs(inputs, input_list)
#    1100
#
# d:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\base_layer.py in _maybe_build(self, inputs)
#    2641         # operations.
#    2642         with tf_utils.maybe_init_scope(self):
# -> 2643           self.build(input_shapes)  # pylint:disable=not-callable
#    2644       # We must set also ensure that the layer is marked as built, and the build
#    2645       # shape is stored since user defined build functions may not be calling
#
# d:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\keras\layers\core.py in build(self, input_shape)
#    1176         constraint=self.kernel_constraint,
#    1177         dtype=self.dtype,
# -> 1178         trainable=True)
#    1179     if self.use_bias:
#    1180       self.bias = self.add_weight(
#
# d:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\base_layer.py in add_weight(self, name, shape, dtype, initializer, regularizer, trainable, constraint, partitioner, use_resource, synchronization, aggregation, **kwargs)
#     612         synchronization=synchronization,
#     613         aggregation=aggregation,
# --> 614         caching_device=caching_device)
#     615     if regularizer is not None:
#     616       # TODO(fchollet): in the future, this should be handled at the
#
# d:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\training\tracking\base.py in _add_variable_with_custom_getter(self, name, shape, dtype, initializer, getter, overwrite, **kwargs_for_getter)
#     748         dtype=dtype,
#     749         initializer=initializer,
# --> 750         **kwargs_for_getter)
#     751
#     752     # If we set an initializer and the variable processed it, tracking will not
#
# d:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\base_layer_utils.py in make_variable(name, shape, dtype, initializer, trainable, caching_device, validate_shape, constraint, use_resource, collections, synchronization, aggregation, partitioner)
#     143       synchronization=synchronization,
#     144       aggregation=aggregation,
# --> 145       shape=variable_shape if variable_shape else None)
#     146
#     147
#
# d:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\ops\variables.py in __call__(cls, *args, **kwargs)
#     258   def __call__(cls, *args, **kwargs):
#     259     if cls is VariableV1:
# --> 260       return cls._variable_v1_call(*args, **kwargs)
#     261     elif cls is Variable:
#     262       return cls._variable_v2_call(*args, **kwargs)
#
# d:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\ops\variables.py in _variable_v1_call(cls, initial_value, trainable, collections, validate_shape, caching_device, name, variable_def, dtype, expected_shape, import_scope, constraint, use_resource, synchronization, aggregation, shape)
#     219         synchronization=synchronization,
#     220         aggregation=aggregation,
# --> 221         shape=shape)
#     222
#     223   def _variable_v2_call(cls,
#
# d:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\ops\variables.py in <lambda>(**kwargs)
#     197                         shape=None):
#     198     """Call on Variable class. Useful to force the signature."""
# --> 199     previous_getter = lambda **kwargs: default_variable_creator(None, **kwargs)
#     200     for _, getter in ops.get_default_graph()._variable_creator_stack:  # pylint: disable=protected-access
#     201       previous_getter = _make_getter(getter, previous_getter)
#
# d:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\ops\variable_scope.py in default_variable_creator(next_creator, **kwargs)
#    2595         synchronization=synchronization,
#    2596         aggregation=aggregation,
# -> 2597         shape=shape)
#    2598   else:
#    2599     return variables.RefVariable(
#
# d:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\ops\variables.py in __call__(cls, *args, **kwargs)
#     262       return cls._variable_v2_call(*args, **kwargs)
#     263     else:
# --> 264       return super(VariableMetaclass, cls).__call__(*args, **kwargs)
#     265
#     266
#
# d:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py in __init__(self, initial_value, trainable, collections, validate_shape, caching_device, name, dtype, variable_def, import_scope, constraint, distribute_strategy, synchronization, aggregation, shape)
#    1516           aggregation=aggregation,
#    1517           shape=shape,
# -> 1518           distribute_strategy=distribute_strategy)
#    1519
#    1520   def _init_from_args(self,
#
# d:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py in _init_from_args(self, initial_value, trainable, collections, caching_device, name, dtype, constraint, synchronization, aggregation, distribute_strategy, shape)
#    1649           with ops.name_scope("Initializer"), device_context_manager(None):
#    1650             initial_value = ops.convert_to_tensor(
# -> 1651                 initial_value() if init_from_fn else initial_value,
#    1652                 name="initial_value", dtype=dtype)
#    1653           if shape is not None:
#
# TypeError: weight_variable() got an unexpected keyword argument 'dtype'

# %%
import numpy as np
from keras.models import Sequential
from keras.layers.core import Dense, Activation
from keras.layers.normalization import BatchNormalization
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping
from sklearn import datasets
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

np.random.seed(123)

'''
데이터를 생성한다
'''
mnist = datasets.fetch_openml('mnist_784')

n = len(mnist.data)
N = 30000  # MNIST의 일부를 사용한다
N_train = 20000
N_validation = 4000
indices = np.random.permutation(range(n))[:N]  # 무작위로 N장을 선택한다

X = mnist.data[indices]
X = X / 255.0
X = X - X.mean(axis=1).reshape(len(X), 1)
y = mnist.target[indices]
Y = np.eye(10)[y.astype(int)]

X_train, X_test, Y_train, Y_test = \
    train_test_split(X, Y, train_size=N_train)
X_train, X_validation, Y_train, Y_validation = \
    train_test_split(X_train, Y_train, test_size=N_validation)

'''
모델을 설정한다
'''
n_in = len(X[0])  # 784
n_hiddens = [200, 200, 200]
n_out = len(Y[0])  # 10
activation = 'relu'


def weight_variable(shape, name=None):
    return np.sqrt(2.0 / shape[0]) * np.random.normal(size=shape)


early_stopping = EarlyStopping(monitor='val_loss', patience=10, verbose=1)

model = Sequential()
for i, input_dim in enumerate(([n_in] + n_hiddens)[:-1]):
    model.add(Dense(n_hiddens[i], input_dim=input_dim,
                    kernel_initializer=weight_variable))
    model.add(BatchNormalization())
    model.add(Activation(activation))

model.add(Dense(n_out, kernel_initializer=weight_variable))
model.add(Activation('softmax'))

model.compile(loss='categorical_crossentropy',
              optimizer=Adam(lr=0.01, beta_1=0.9, beta_2=0.999),
              metrics=['accuracy'])

'''
모델을 학습시킨다
'''
epochs = 200
batch_size = 200

hist = model.fit(X_train, Y_train, epochs=epochs,
                 batch_size=batch_size,
                 validation_data=(X_validation, Y_validation),
                 callbacks=[early_stopping])

'''
학습이 진행되는 상황을 가시화한다
'''
val_acc = hist.history['val_acc']
val_loss = hist.history['val_loss']

plt.rc('font', family='serif')
fig = plt.figure()
plt.plot(range(len(val_loss)), val_loss, label='loss', color='black')
plt.xlabel('epochs')
plt.show()

'''
예측 정확도를 평가한다
'''
loss_and_metrics = model.evaluate(X_test, Y_test)
print(loss_and_metrics)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-c32058ffae14> in <module>
#      51 for i, input_dim in enumerate(([n_in] + n_hiddens)[:-1]):
#      52     model.add(Dense(n_hiddens[i], input_dim=input_dim,
# ---> 53                     kernel_initializer=weight_variable))
#      54     model.add(BatchNormalization())
#      55     model.add(Activation(activation))
#
# d:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\training\tracking\base.py in _method_wrapper(self, *args, **kwargs)
#     455     self._self_setattr_tracking = False  # pylint: disable=protected-access
#     456     try:
# --> 457       result = method(self, *args, **kwargs)
#     458     finally:
#     459       self._self_setattr_tracking = previous_value  # pylint: disable=protected-access
#
# d:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\sequential.py in add(self, layer)
#     204           # and create the node connecting the current layer
#     205           # to the input layer we just created.
# --> 206           layer(x)
#     207           set_inputs = True
#     208
#
# d:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\base_layer.py in __call__(self, *args, **kwargs)
#     924     if _in_functional_construction_mode(self, inputs, args, kwargs, input_list):
#     925       return self._functional_construction_call(inputs, args, kwargs,
# --> 926                                                 input_list)
#     927
#     928     # Maintains info about the `Layer.call` stack.
#
# d:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\base_layer.py in _functional_construction_call(self, inputs, args, kwargs, input_list)
#    1096         # Build layer if applicable (if the `build` method has been
#    1097         # overridden).
# -> 1098         self._maybe_build(inputs)
#    1099         cast_inputs = self._maybe_cast_inputs(inputs, input_list)
#    1100
#
# d:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\base_layer.py in _maybe_build(self, inputs)
#    2641         # operations.
#    2642         with tf_utils.maybe_init_scope(self):
# -> 2643           self.build(input_shapes)  # pylint:disable=not-callable
#    2644       # We must set also ensure that the layer is marked as built, and the build
#    2645       # shape is stored since user defined build functions may not be calling
#
# d:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\keras\layers\core.py in build(self, input_shape)
#    1176         constraint=self.kernel_constraint,
#    1177         dtype=self.dtype,
# -> 1178         trainable=True)
#    1179     if self.use_bias:
#    1180       self.bias = self.add_weight(
#
# d:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\base_layer.py in add_weight(self, name, shape, dtype, initializer, regularizer, trainable, constraint, partitioner, use_resource, synchronization, aggregation, **kwargs)
#     612         synchronization=synchronization,
#     613         aggregation=aggregation,
# --> 614         caching_device=caching_device)
#     615     if regularizer is not None:
#     616       # TODO(fchollet): in the future, this should be handled at the
#
# d:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\training\tracking\base.py in _add_variable_with_custom_getter(self, name, shape, dtype, initializer, getter, overwrite, **kwargs_for_getter)
#     748         dtype=dtype,
#     749         initializer=initializer,
# --> 750         **kwargs_for_getter)
#     751
#     752     # If we set an initializer and the variable processed it, tracking will not
#
# d:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\base_layer_utils.py in make_variable(name, shape, dtype, initializer, trainable, caching_device, validate_shape, constraint, use_resource, collections, synchronization, aggregation, partitioner)
#     143       synchronization=synchronization,
#     144       aggregation=aggregation,
# --> 145       shape=variable_shape if variable_shape else None)
#     146
#     147
#
# d:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\ops\variables.py in __call__(cls, *args, **kwargs)
#     258   def __call__(cls, *args, **kwargs):
#     259     if cls is VariableV1:
# --> 260       return cls._variable_v1_call(*args, **kwargs)
#     261     elif cls is Variable:
#     262       return cls._variable_v2_call(*args, **kwargs)
#
# d:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\ops\variables.py in _variable_v1_call(cls, initial_value, trainable, collections, validate_shape, caching_device, name, variable_def, dtype, expected_shape, import_scope, constraint, use_resource, synchronization, aggregation, shape)
#     219         synchronization=synchronization,
#     220         aggregation=aggregation,
# --> 221         shape=shape)
#     222
#     223   def _variable_v2_call(cls,
#
# d:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\ops\variables.py in <lambda>(**kwargs)
#     197                         shape=None):
#     198     """Call on Variable class. Useful to force the signature."""
# --> 199     previous_getter = lambda **kwargs: default_variable_creator(None, **kwargs)
#     200     for _, getter in ops.get_default_graph()._variable_creator_stack:  # pylint: disable=protected-access
#     201       previous_getter = _make_getter(getter, previous_getter)
#
# d:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\ops\variable_scope.py in default_variable_creator(next_creator, **kwargs)
#    2595         synchronization=synchronization,
#    2596         aggregation=aggregation,
# -> 2597         shape=shape)
#    2598   else:
#    2599     return variables.RefVariable(
#
# d:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\ops\variables.py in __call__(cls, *args, **kwargs)
#     262       return cls._variable_v2_call(*args, **kwargs)
#     263     else:
# --> 264       return super(VariableMetaclass, cls).__call__(*args, **kwargs)
#     265
#     266
#
# d:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py in __init__(self, initial_value, trainable, collections, validate_shape, caching_device, name, dtype, variable_def, import_scope, constraint, distribute_strategy, synchronization, aggregation, shape)
#    1516           aggregation=aggregation,
#    1517           shape=shape,
# -> 1518           distribute_strategy=distribute_strategy)
#    1519
#    1520   def _init_from_args(self,
#
# d:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py in _init_from_args(self, initial_value, trainable, collections, caching_device, name, dtype, constraint, synchronization, aggregation, distribute_strategy, shape)
#    1649           with ops.name_scope("Initializer"), device_context_manager(None):
#    1650             initial_value = ops.convert_to_tensor(
# -> 1651                 initial_value() if init_from_fn else initial_value,
#    1652                 name="initial_value", dtype=dtype)
#    1653           if shape is not None:
#
# TypeError: weight_variable() got an unexpected keyword argument 'dtype'
